# %% [markdown]
# # Import modules

# %%
import pandas as pd
import numpy as np

# preprocessing
from sklearn.impute          import SimpleImputer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing   import StandardScaler, OneHotEncoder, OrdinalEncoder

# estimators
from sklearn.ensemble        import RandomForestClassifier
from sklearn.linear_model    import LogisticRegression
from sklearn.neighbors       import KNeighborsClassifier
from sklearn.svm             import SVC

# pipeline
from sklearn.compose         import ColumnTransformer
from sklearn.pipeline        import Pipeline

# metrics
from sklearn.metrics         import accuracy_score, confusion_matrix, precision_score, precision_recall_curve, \
                                    recall_score, f1_score, fbeta_score, precision_recall_fscore_support, average_precision_score

from json import dumps
# import plotly.express as px

# %%
from sklearn import set_config
set_config(transform_output='pandas')

# %%
# %pdb on
# Out:
# Automatic pdb calling has been turned ON

# %% [markdown]
# # Global settings

# %%
RANDOM_STATE = 123

# %% [markdown]
# # Load data

# %%
df = pd.read_csv('../housing-classification-iter6.csv')

# %%
df.columns = df.columns.str.strip()
scol = sorted(df.columns)
df = df[scol]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   1stFlrSF       1460 non-null   int64
#  1   2ndFlrSF       1460 non-null   int64
#  2   3SsnPorch      1460 non-null   int64
#  3   Alley          91 non-null     object
#  4   BedroomAbvGr   1460 non-null   int64
#  5   BldgType       1460 non-null   object
#  6   BsmtCond       1423 non-null   object
#  7   BsmtExposure   1422 non-null   object
#  8   BsmtFinSF1     1460 non-null   int64
#  9   BsmtFinSF2     1460 non-null   int64
#  10  BsmtFinType1   1423 non-null   object
#  11  BsmtFinType2   1422 non-null   object
#  12  BsmtFullBath   1460 non-null   int64
#  13  BsmtHalfBath   1460 non-null   int64
#  14  BsmtQual       1423 non-null   object
#  15  BsmtUnfSF      1460 non-null   int64
#  16  CentralAir     1460 non-null   object
#  17  Condition1     1460 non-null   object
#  18  Condition2     1460 non-null   object
#  19  Electrical     1459 non-null   object
#  20  EnclosedPorch  1460 non-null   int64
#  21  Expensive      1460 non-null   int64
#  22  ExterCond      1460 non-null   object
#  23  ExterQual      1460 non-null   object
#  24  Exterior1st    1460 non-null   object
#  25  Exterior2nd    1460 non-null   object
#  26  Fence          281 non-null    object
#  27  FireplaceQu    770 non-null    object
#  28  Fireplaces     1460 non-null   int64
#  29  Foundation     1460 non-null   object
#  30  FullBath       1460 non-null   int64
#  31  Functional     1460 non-null   object
#  32  GarageArea     1460 non-null   int64
#  33  GarageCars     1460 non-null   int64
#  34  GarageCond     1379 non-null   object
#  35  GarageFinish   1379 non-null   object
#  36  GarageQual     1379 non-null   object
#  37  GarageType     1379 non-null   object
#  38  GarageYrBlt    1379 non-null   float64
#  39  GrLivArea      1460 non-null   int64
#  40  HalfBath       1460 non-null   int64
#  41  Heating        1460 non-null   object
#  42  HeatingQC      1460 non-null   object
#  43  HouseStyle     1460 non-null   object
#  44  Id             1460 non-null   int64
#  45  KitchenAbvGr   1460 non-null   int64
#  46  KitchenQual    1460 non-null   object
#  47  LandContour    1460 non-null   object
#  48  LandSlope      1460 non-null   object
#  49  LotArea        1460 non-null   int64
#  50  LotConfig      1460 non-null   object
#  51  LotFrontage    1201 non-null   float64
#  52  LotShape       1460 non-null   object
#  53  LowQualFinSF   1460 non-null   int64
#  54  MSSubClass     1460 non-null   int64
#  55  MSZoning       1460 non-null   object
#  56  MasVnrArea     1452 non-null   float64
#  57  MasVnrType     1452 non-null   object
#  58  MiscFeature    54 non-null     object
#  59  MiscVal        1460 non-null   int64
#  60  MoSold         1460 non-null   int64
#  61  Neighborhood   1460 non-null   object
#  62  OpenPorchSF    1460 non-null   int64
#  63  OverallCond    1460 non-null   int64
#  64  OverallQual    1460 non-null   int64
#  65  PavedDrive     1460 non-null   object
#  66  PoolArea       1460 non-null   int64
#  67  PoolQC         7 non-null      object
#  68  RoofMatl       1460 non-null   object
#  69  RoofStyle      1460 non-null   object
#  70  SaleCondition  1460 non-null   object
#  71  SaleType       1460 non-null   object
#  72  ScreenPorch    1460 non-null   int64
#  73  Street         1460 non-null   object
#  74  TotRmsAbvGrd   1460 non-null   int64
#  75  TotalBsmtSF    1460 non-null   int64
#  76  Utilities      1460 non-null   object
#  77  WoodDeckSF     1460 non-null   int64
#  78  YearBuilt      1460 non-null   int64
#  79  YearRemodAdd   1460 non-null   int64
#  80  YrSold         1460 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %%
# drop nan columns
df = df.drop(columns=['Id', 'Alley', 'PoolQC', 'Fence', 'MiscFeature'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 76 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   1stFlrSF       1460 non-null   int64
#  1   2ndFlrSF       1460 non-null   int64
#  2   3SsnPorch      1460 non-null   int64
#  3   BedroomAbvGr   1460 non-null   int64
#  4   BldgType       1460 non-null   object
#  5   BsmtCond       1423 non-null   object
#  6   BsmtExposure   1422 non-null   object
#  7   BsmtFinSF1     1460 non-null   int64
#  8   BsmtFinSF2     1460 non-null   int64
#  9   BsmtFinType1   1423 non-null   object
#  10  BsmtFinType2   1422 non-null   object
#  11  BsmtFullBath   1460 non-null   int64
#  12  BsmtHalfBath   1460 non-null   int64
#  13  BsmtQual       1423 non-null   object
#  14  BsmtUnfSF      1460 non-null   int64
#  15  CentralAir     1460 non-null   object
#  16  Condition1     1460 non-null   object
#  17  Condition2     1460 non-null   object
#  18  Electrical     1459 non-null   object
#  19  EnclosedPorch  1460 non-null   int64
#  20  Expensive      1460 non-null   int64
#  21  ExterCond      1460 non-null   object
#  22  ExterQual      1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  FireplaceQu    770 non-null    object
#  26  Fireplaces     1460 non-null   int64
#  27  Foundation     1460 non-null   object
#  28  FullBath       1460 non-null   int64
#  29  Functional     1460 non-null   object
#  30  GarageArea     1460 non-null   int64
#  31  GarageCars     1460 non-null   int64
#  32  GarageCond     1379 non-null   object
#  33  GarageFinish   1379 non-null   object
#  34  GarageQual     1379 non-null   object
#  35  GarageType     1379 non-null   object
#  36  GarageYrBlt    1379 non-null   float64
#  37  GrLivArea      1460 non-null   int64
#  38  HalfBath       1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  HouseStyle     1460 non-null   object
#  42  KitchenAbvGr   1460 non-null   int64
#  43  KitchenQual    1460 non-null   object
#  44  LandContour    1460 non-null   object
#  45  LandSlope      1460 non-null   object
#  46  LotArea        1460 non-null   int64
#  47  LotConfig      1460 non-null   object
#  48  LotFrontage    1201 non-null   float64
#  49  LotShape       1460 non-null   object
#  50  LowQualFinSF   1460 non-null   int64
#  51  MSSubClass     1460 non-null   int64
#  52  MSZoning       1460 non-null   object
#  53  MasVnrArea     1452 non-null   float64
#  54  MasVnrType     1452 non-null   object
#  55  MiscVal        1460 non-null   int64
#  56  MoSold         1460 non-null   int64
#  57  Neighborhood   1460 non-null   object
#  58  OpenPorchSF    1460 non-null   int64
#  59  OverallCond    1460 non-null   int64
#  60  OverallQual    1460 non-null   int64
#  61  PavedDrive     1460 non-null   object
#  62  PoolArea       1460 non-null   int64
#  63  RoofMatl       1460 non-null   object
#  64  RoofStyle      1460 non-null   object
#  65  SaleCondition  1460 non-null   object
#  66  SaleType       1460 non-null   object
#  67  ScreenPorch    1460 non-null   int64
#  68  Street         1460 non-null   object
#  69  TotRmsAbvGrd   1460 non-null   int64
#  70  TotalBsmtSF    1460 non-null   int64
#  71  Utilities      1460 non-null   object
#  72  WoodDeckSF     1460 non-null   int64
#  73  YearBuilt      1460 non-null   int64
#  74  YearRemodAdd   1460 non-null   int64
#  75  YrSold         1460 non-null   int64
# dtypes: float64(3), int64(34), object(39)
# memory usage: 867.0+ KB

# %%
X = df.copy()
y = X.pop('Expensive')

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=RANDOM_STATE)

# %% [markdown]
# ## Clean and prepare data

# %%
X_train
# Out:
#       1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr BldgType BsmtCond  \
# 318       1372      1274          0             4     1Fam       TA
# 580       1429         0          0             3     1Fam       TA
# 961       1542      1330          0             4     1Fam       Gd
# 78        1768         0          0             4   Duplex       TA
# 5          796       566        320             1     1Fam       TA
# ...        ...       ...        ...           ...      ...      ...
# 1041       800       832          0             4     1Fam       TA
# 1122       960         0          0             3     1Fam       TA
# 1346      2156         0        290             3     1Fam       TA
# 1406       768         0          0             2     1Fam       TA
# 1389       869       349          0             3     1Fam       Gd
#
#      BsmtExposure  BsmtFinSF1  BsmtFinSF2 BsmtFinType1  ... SaleType  \
# 318            Gd         987           0          GLQ  ...       WD
# 580            No         594         219          BLQ  ...       WD
# 961            No         896           0          ALQ  ...       WD
# 78             No           0           0          Unf  ...       WD
# 5              No         732           0          GLQ  ...       WD
# ...           ...         ...         ...          ...  ...      ...
# 1041           No         400          64          GLQ  ...       WD
# 1122           No           0           0          Unf  ...      COD
# 1346           No         297          68          BLQ  ...       WD
# 1406           Av         656           0          GLQ  ...       WD
# 1389           No         375           0          ALQ  ...       WD
#
#       ScreenPorch  Street TotRmsAbvGrd  TotalBsmtSF Utilities WoodDeckSF  \
# 318             0    Pave            9         1347    AllPub        340
# 580             0    Pave            7         1144    AllPub        216
# 961             0    Pave           11         1330    AllPub        550
# 78              0    Pave            8         1768    AllPub          0
# 5               0    Pave            5          796    AllPub         40
# ...           ...     ...          ...          ...       ...        ...
# 1041            0    Pave            7          800    AllPub          0
# 1122          160    Pave            5          672    AllPub         64
# 1346            0    Pave            9         1568    AllPub          0
# 1406            0    Pave            5          768    AllPub         58
# 1389            0    Pave            6          735    AllPub          0
#
#      YearBuilt YearRemodAdd  YrSold
# 318       1993         1993    2009
# 580       1960         1987    2007
# 961       1977         1995    2008
# 78        1968         1968    2010
# 5         1993         1995    2009
# ...        ...          ...     ...
# 1041      1966         2000    2008
# 1122      1956         1956    2009
# 1346      1968         2003    2006
# 1406      1972         2007    2009
# 1389      1941         1950    2007
#
# [1168 rows x 75 columns]

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1168 entries, 318 to 1389
# Data columns (total 75 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   1stFlrSF       1168 non-null   int64
#  1   2ndFlrSF       1168 non-null   int64
#  2   3SsnPorch      1168 non-null   int64
#  3   BedroomAbvGr   1168 non-null   int64
#  4   BldgType       1168 non-null   object
#  5   BsmtCond       1139 non-null   object
#  6   BsmtExposure   1138 non-null   object
#  7   BsmtFinSF1     1168 non-null   int64
#  8   BsmtFinSF2     1168 non-null   int64
#  9   BsmtFinType1   1139 non-null   object
#  10  BsmtFinType2   1139 non-null   object
#  11  BsmtFullBath   1168 non-null   int64
#  12  BsmtHalfBath   1168 non-null   int64
#  13  BsmtQual       1139 non-null   object
#  14  BsmtUnfSF      1168 non-null   int64
#  15  CentralAir     1168 non-null   object
#  16  Condition1     1168 non-null   object
#  17  Condition2     1168 non-null   object
#  18  Electrical     1167 non-null   object
#  19  EnclosedPorch  1168 non-null   int64
#  20  ExterCond      1168 non-null   object
#  21  ExterQual      1168 non-null   object
#  22  Exterior1st    1168 non-null   object
#  23  Exterior2nd    1168 non-null   object
#  24  FireplaceQu    613 non-null    object
#  25  Fireplaces     1168 non-null   int64
#  26  Foundation     1168 non-null   object
#  27  FullBath       1168 non-null   int64
#  28  Functional     1168 non-null   object
#  29  GarageArea     1168 non-null   int64
#  30  GarageCars     1168 non-null   int64
#  31  GarageCond     1101 non-null   object
#  32  GarageFinish   1101 non-null   object
#  33  GarageQual     1101 non-null   object
#  34  GarageType     1101 non-null   object
#  35  GarageYrBlt    1101 non-null   float64
#  36  GrLivArea      1168 non-null   int64
#  37  HalfBath       1168 non-null   int64
#  38  Heating        1168 non-null   object
#  39  HeatingQC      1168 non-null   object
#  40  HouseStyle     1168 non-null   object
#  41  KitchenAbvGr   1168 non-null   int64
#  42  KitchenQual    1168 non-null   object
#  43  LandContour    1168 non-null   object
#  44  LandSlope      1168 non-null   object
#  45  LotArea        1168 non-null   int64
#  46  LotConfig      1168 non-null   object
#  47  LotFrontage    979 non-null    float64
#  48  LotShape       1168 non-null   object
#  49  LowQualFinSF   1168 non-null   int64
#  50  MSSubClass     1168 non-null   int64
#  51  MSZoning       1168 non-null   object
#  52  MasVnrArea     1164 non-null   float64
#  53  MasVnrType     1164 non-null   object
#  54  MiscVal        1168 non-null   int64
#  55  MoSold         1168 non-null   int64
#  56  Neighborhood   1168 non-null   object
#  57  OpenPorchSF    1168 non-null   int64
#  58  OverallCond    1168 non-null   int64
#  59  OverallQual    1168 non-null   int64
#  60  PavedDrive     1168 non-null   object
#  61  PoolArea       1168 non-null   int64
#  62  RoofMatl       1168 non-null   object
#  63  RoofStyle      1168 non-null   object
#  64  SaleCondition  1168 non-null   object
#  65  SaleType       1168 non-null   object
#  66  ScreenPorch    1168 non-null   int64
#  67  Street         1168 non-null   object
#  68  TotRmsAbvGrd   1168 non-null   int64
#  69  TotalBsmtSF    1168 non-null   int64
#  70  Utilities      1168 non-null   object
#  71  WoodDeckSF     1168 non-null   int64
#  72  YearBuilt      1168 non-null   int64
#  73  YearRemodAdd   1168 non-null   int64
#  74  YrSold         1168 non-null   int64
# dtypes: float64(3), int64(33), object(39)
# memory usage: 693.5+ KB

# %%
X_train.isna().sum()
# Out:
# 1stFlrSF        0
# 2ndFlrSF        0
# 3SsnPorch       0
# BedroomAbvGr    0
# BldgType        0
#                ..
# Utilities       0
# WoodDeckSF      0
# YearBuilt       0
# YearRemodAdd    0
# YrSold          0
# Length: 75, dtype: int64

# %%
# categorical features

# cat_idx = list(range(9, 26))
# more_cats = list(range(50, 75))
# cat_idx = cat_idx + more_cats
# X_train_cat = X_train.iloc[:, cat_idx]
X_train_cat_cols = [
    'BldgType',
    'BsmtCond',
    'BsmtExposure',
    'BsmtFinType1',
    'BsmtFinType2',
    'BsmtQual',
    'CentralAir',
    'Condition1',
    'Condition2',
    'Electrical',
    'ExterCond',
    'ExterQual',
    'Exterior1st',
    'Exterior2nd',
    'FireplaceQu',
    'Foundation',
    'Functional',
    'GarageCond',
    'GarageFinish',
    'GarageQual',
    'GarageType',
    'Heating',
    'HeatingQC',
    'HouseStyle',
    'KitchenQual',
    'LandContour',
    'LandSlope',
    'LotConfig',
    'LotShape',
    'MSSubClass',
    'MSZoning',
    'MasVnrType',
    'Neighborhood',
    'OverallCond',
    'OverallQual',
    'PavedDrive',
    'RoofMatl',
    'RoofStyle',
    'SaleCondition',
    'SaleType',
    'Street',
    'Utilities',
]

X_train_cat = X_train[X_train_cat_cols]

# %%
# numerical features

X_train_num_cols = list(set(X_train.columns) - set(X_train_cat_cols))
X_train_num = X_train[X_train_num_cols]

# %% [markdown]
# # Pipeline

# %% [markdown]
# ## categorical pipeline

# %%
X_train_cat_ord  = [
    'ExterQual',
    'ExterCond',
    'BsmtQual',
    'BsmtCond',
    'BsmtExposure',
    'BsmtFinType1',
    'KitchenQual',
    'FireplaceQu',
    'OverallQual',
    'OverallCond',
    'GarageQual',
    'GarageCond'
    # 'PoolQC',
    # 'Fence'
]
X_train_cat_nonord  = list(set(X_train_cat_cols) - set(X_train_cat_ord))

# %%
ord_categories = [
    ['Po', 'Fa', 'TA', 'Gd', 'Ex'],
    ['Po', 'Fa', 'TA', 'Gd', 'Ex'],
    ['Po', 'Fa', 'TA', 'Gd', 'Ex'],
    ['Po', 'Fa', 'TA', 'Gd', 'Ex'],
    ['No', 'Mn', 'Av', 'Gd'],
    ['Unf', 'LwQ', 'Rec', 'BLQ', 'ALQ', 'GLQ'],
    ['Po', 'Fa', 'TA', 'Gd', 'Ex'],
    ['Po', 'Fa', 'TA', 'Gd', 'Ex'],
    list(range(1, 11)),
    list(range(1, 11)),
    ['Po', 'Fa', 'TA', 'Gd', 'Ex'],
    ['Po', 'Fa', 'TA', 'Gd', 'Ex']
    # ['Fa', 'TA', 'Gd', 'Ex'],
    # ['MvWw', 'GdWo', 'MnPrv', 'GdPrv']
]
unknown_value  = -1

# %%
encoders = ColumnTransformer(
    transformers=[
        ('ordinal', OrdinalEncoder(categories=ord_categories, handle_unknown='use_encoded_value', unknown_value=unknown_value), X_train_cat_ord),
        ('nonordinal', OneHotEncoder(handle_unknown='ignore', sparse_output=False), X_train_cat_nonord)
    ]
)

# %%
cat_pipe = Pipeline([
    ('imputer', SimpleImputer(strategy='constant', fill_value='N_A')),
    ('encoders', encoders)
])

# %% [markdown]
# ## numerical pipeline

# %%
num_pipe = Pipeline([
    ('imputer', SimpleImputer()),
    ('scaler', StandardScaler())
])

# %% [markdown]
# ## estimators

# %%
estimators = {
    'KNN': [KNeighborsClassifier(), {
        'estimator__n_neighbors': range(3, 9),
        'estimator__weights': ['uniform', 'distance'],
        'estimator__leaf_size': range(5, 15)
    }],
    # 'LR': [LogisticRegression(random_state=RANDOM_STATE), {
    #     'estimator__tol': np.arange(5e-6, 5e-5, 1e-6)
    # }],
    # 'SVC': [SVC(random_state=RANDOM_STATE), {
    #     'estimator__gamma': ['scale', 'auto']
    # }],
    # 'RF': [RandomForestClassifier(random_state=RANDOM_STATE), {
    #     'estimator__n_estimators': range(90, 100, 1),
    #     'estimator__criterion': ['gini', 'entropy', 'log_loss']
    # }]
}

# %% [markdown]
# ## full pipeline

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('cat_pipe', cat_pipe, X_train_cat_cols),
        ('num_pipe', num_pipe, X_train_num_cols),
    ]
)

# %%
def create_pipeline_and_cvparams(preprocessor, estimator):

    pipe = Pipeline([
        ('preprocessor', preprocessor),
        ('estimator', estimator[1][0])
    ])

    cvparams = estimator[1][1]

    return pipe, cvparams

# %%
# nord_stream, params_est = create_pipeline_and_cvparams(preprocessor, estimator=estimators['KNN'])

# %%
# nord_stream.fit(X_train, y_train)

# %%
# y_pred = nord_stream.predict(X_test)

# %% [markdown]
# # Cross validation

# %%
params_pre = {
    "preprocessor__num_pipe__imputer__strategy": ["mean", "median"],
    "preprocessor__num_pipe__scaler__with_mean": [True, False],
    "preprocessor__num_pipe__scaler__with_std": [True, False]
}

# %% [markdown]
# # Model evaluation

# %%
def evaluate_model(y_true, y_pred, beta=1):

    output = {}

    output['conf_matrix'] = confusion_matrix(y_true=y_true, y_pred=y_pred)
    output['acc_score']   = accuracy_score(  y_true=y_true, y_pred=y_pred)
    output['prec_score']  = precision_score( y_true=y_true, y_pred=y_pred)
    output['f1_score']    = f1_score(        y_true=y_true, y_pred=y_pred)
    output['fbeta_score'] = fbeta_score(     y_true=y_true, y_pred=y_pred, beta=beta)

    # support                      = precision_recall_fscore_support(y_true=y_true, y_pred=y_pred, beta=beta)
    # precision, recall, threshold = precision_recall_curve(y_true=y_true, y_score=y_score)
    # ave_score                    = average_precision_score(y_true=y_true, y_score=y_score)

    return output

# %% [markdown]
# # Create and run model

# %%
def run_model(xtrain, ytrain, xtest, ytest, params_pre, preprocessor, estimator, cv):

    pipe, params_est = create_pipeline_and_cvparams(preprocessor, estimator=estimator)

    if params_est:
        params = params_pre | params_est
    else:
        params = params_pre

    grid = GridSearchCV(pipe, params, cv=cv, verbose=1)
    grid.fit(xtrain, ytrain)

    grid_score       = grid.best_score_
    grid_best_params = grid.best_params_
    best_estimator   = grid.best_estimator_

    acc_score = accuracy_score(y_true=ytest, y_pred=grid.predict(xtest))

    # estimator_evaluation = evaluate_model(ytest, best_estimator.predict(xtest))

    return best_estimator, grid_best_params, grid_score, acc_score #, estimator_evaluation

# %%
total = {}
for estimator in estimators.items():
    model, best_params, grid_score, acc_score = run_model(
        xtrain=X_train,
        ytrain=y_train,
        xtest=X_test,
        ytest=y_test,
        params_pre=params_pre,
        preprocessor=preprocessor,
        estimator=estimator,
        cv=3
    )

    total[estimator[0]] = {
        'model': model,
        'best_params': best_params,
        'grid_score': grid_score,
        'acc_score': acc_score
        # 'eval_results': eval_results
    }
# Out:
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fda8aee85e0>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fda8aee9b20>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fda8aeca160>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Fitting 3 folds for each of 960 candidates, totalling 2880 fits
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fda8ae8e160>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fda8ae8e160>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fda8ae8e160>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fda8ae8e160>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fdafaffc360>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fda8aeca980>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fda8aeca160>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fda8aeca980>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fda8aeca160>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fdafaffc360>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fda8aeca980>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fda8aeca980>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fda8aecade0>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fda8aecb060>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fdafaffc360>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fda8aecade0>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fda8aeca160>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fda8aecb060>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fdafaffc360>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fdafaffc360>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fdafaffc360>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fdafaffc360>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fdafaffc360>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fdafaffc360>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fdafaffc360>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fdafaffc360>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fdafaffc360>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fdafaffc360>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fdafaffc360>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fdafaffc360>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fda8aecb060>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fda8aecb060>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fda8aecade0>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fda8aecb060>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fdafaffc360>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fda8aeca980>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fda8aecb060>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fda8aeca980>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fdafaffc360>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fda8aecade0>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fda8aeca160>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# ...
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fdafaffc360>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fdafaffc360>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fdafaffc360>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fdafaffc360>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fdafaffc360>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fdafaffc360>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fdafaffc360>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fdafaffc360>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fdafaffc360>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fdafaffc360>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fdafaffc360>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fdafaffc360>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fdafaffc360>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fdafaffc220>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'

# %%
for key in total.keys():
    print(key)
    print('='*50)
    for i, j in total[key].items():
        if (i != 'model'):
            print(i)
            print(j)
            print()
# Out:
# KNN
# ==================================================
# best_params
# {'estimator__leaf_size': 5, 'estimator__n_neighbors': 7, 'estimator__weights': 'uniform', 'preprocessor__num_pipe__imputer__strategy': 'mean', 'preprocessor__num_pipe__scaler__with_mean': True, 'preprocessor__num_pipe__scaler__with_std': True}
#
# grid_score
# 0.9356252975159355
#
# acc_score
# 0.9691780821917808

# %%
model = total['KNN']['model']
model
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat_pipe',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value='N_A',
#                                                                                  strategy='constant')),
#                                                                   ('encoders',
#                                                                    ColumnTransformer(transformers=[('ordinal',
#                                                                                                     OrdinalEncoder(categories=[['Po',
#                                                                                                                                 'Fa',
#                                                                                                                                 'TA',
#                                                                                                                                 'Gd',
#                                                                                                                                 'Ex'],
#                                                                                                                                ['Po',
#                                                                                                                                 'Fa',
#                                                                                                                                 'TA',
#                                                                                                                                 'Gd',
#                                                                                                                                 'Ex'],
#                                                                                                                                ['Po',
#                                                                                                                                 'Fa',
#                                                                                                                                 'TA',
#                                                                                                                                 'Gd',
#                                                                                                                                 'Ex'],
#                                                                                                                                ['Po',
#                                                                                                                                 'Fa',
#                                                                                                                                 'TA',
#                                                                                                                                 'Gd',
#                                                                                                                                 'Ex'],
#                                                                                                                                ['No...
#                                                    'BedroomAbvGr',
#                                                    'OpenPorchSF', 'YearBuilt',
#                                                    'PoolArea', 'YearRemodAdd',
#                                                    'GarageArea', 'BsmtHalfBath',
#                                                    'LotFrontage', '3SsnPorch',
#                                                    'YrSold', '1stFlrSF',
#                                                    'BsmtFinSF2',
#                                                    'EnclosedPorch', 'MiscVal',
#                                                    'GrLivArea', 'LowQualFinSF',
#                                                    'GarageYrBlt',
#                                                    'KitchenAbvGr', 'BsmtUnfSF',
#                                                    'MoSold', 'TotalBsmtSF',
#                                                    'GarageCars', ...])])),
#                 ('estimator',
#                  KNeighborsClassifier(leaf_size=10, n_neighbors=7))])

# %%
print(model)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat_pipe',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value='N_A',
#                                                                                  strategy='constant')),
#                                                                   ('encoders',
#                                                                    ColumnTransformer(transformers=[('ordinal',
#                                                                                                     OrdinalEncoder(categories=[['Po',
#                                                                                                                                 'Fa',
#                                                                                                                                 'TA',
#                                                                                                                                 'Gd',
#                                                                                                                                 'Ex'],
#                                                                                                                                ['Po',
#                                                                                                                                 'Fa',
#                                                                                                                                 'TA',
#                                                                                                                                 'Gd',
#                                                                                                                                 'Ex'],
#                                                                                                                                ['Po',
#                                                                                                                                 'Fa',
#                                                                                                                                 'TA',
#                                                                                                                                 'Gd',
#                                                                                                                                 'Ex'],
#                                                                                                                                ['Po',
#                                                                                                                                 'Fa',
#                                                                                                                                 'TA',
#                                                                                                                                 'Gd',
#                                                                                                                                 'Ex'],
#                                                                                                                                ['No...
#                                                    'BedroomAbvGr',
#                                                    'OpenPorchSF', 'YearBuilt',
#                                                    'PoolArea', 'YearRemodAdd',
#                                                    'GarageArea', 'BsmtHalfBath',
#                                                    'LotFrontage', '3SsnPorch',
#                                                    'YrSold', '1stFlrSF',
#                                                    'BsmtFinSF2',
#                                                    'EnclosedPorch', 'MiscVal',
#                                                    'GrLivArea', 'LowQualFinSF',
#                                                    'GarageYrBlt',
#                                                    'KitchenAbvGr', 'BsmtUnfSF',
#                                                    'MoSold', 'TotalBsmtSF',
#                                                    'GarageCars', ...])])),
#                 ('estimator',
#                  KNeighborsClassifier(leaf_size=10, n_neighbors=7))])

# %% [markdown]
# # Final testing

# %% [markdown]
# ## Load test data

# %%
test = pd.read_csv('test.csv')

# %%
test.columns = test.columns.str.strip()
tscol = sorted(test.columns)
test = test[tscol]
test
# Out:
#       1stFlrSF  2ndFlrSF  3SsnPorch Alley  BedroomAbvGr BldgType BsmtCond  \
# 0          896         0          0   NaN             2     1Fam       TA
# 1         1329         0          0   NaN             3     1Fam       TA
# 2          928       701          0   NaN             3     1Fam       TA
# 3          926       678          0   NaN             3     1Fam       TA
# 4         1280         0          0   NaN             2   TwnhsE       TA
# ...        ...       ...        ...   ...           ...      ...      ...
# 1454       546       546          0   NaN             3    Twnhs       TA
# 1455       546       546          0   NaN             3   TwnhsE       TA
# 1456      1224         0          0   NaN             4     1Fam       TA
# 1457       970         0          0   NaN             3     1Fam       TA
# 1458       996      1004          0   NaN             3     1Fam       TA
#
#      BsmtExposure  BsmtFinSF1  BsmtFinSF2  ... SaleType ScreenPorch  Street  \
# 0              No       468.0       144.0  ...       WD         120    Pave
# 1              No       923.0         0.0  ...       WD           0    Pave
# 2              No       791.0         0.0  ...       WD           0    Pave
# 3              No       602.0         0.0  ...       WD           0    Pave
# 4              No       263.0         0.0  ...       WD         144    Pave
# ...           ...         ...         ...  ...      ...         ...     ...
# 1454           No         0.0         0.0  ...       WD           0    Pave
# 1455           No       252.0         0.0  ...       WD           0    Pave
# 1456           No      1224.0         0.0  ...       WD           0    Pave
# 1457           Av       337.0         0.0  ...       WD           0    Pave
# 1458           Av       758.0         0.0  ...       WD           0    Pave
#
#       TotRmsAbvGrd TotalBsmtSF  Utilities WoodDeckSF YearBuilt YearRemodAdd  \
# 0                5       882.0     AllPub        140      1961         1961
# 1                6      1329.0     AllPub        393      1958         1958
# 2                6       928.0     AllPub        212      1997         1998
# 3                7       926.0     AllPub        360      1998         1998
# 4                5      1280.0     AllPub          0      1992         1992
# ...            ...         ...        ...        ...       ...          ...
# 1454             5       546.0     AllPub          0      1970         1970
# 1455             6       546.0     AllPub          0      1970         1970
# 1456             7      1224.0     AllPub        474      1960         1996
# 1457             6       912.0     AllPub         80      1992         1992
# 1458             9       996.0     AllPub        190      1993         1994
#
#      YrSold
# 0      2010
# 1      2010
# 2      2010
# 3      2010
# 4      2010
# ...     ...
# 1454   2006
# 1455   2006
# 1456   2006
# 1457   2006
# 1458   2006
#
# [1459 rows x 81 columns]

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   1stFlrSF       1459 non-null   int64
#  1   2ndFlrSF       1459 non-null   int64
#  2   3SsnPorch      1459 non-null   int64
#  3   Alley          107 non-null    object
#  4   BedroomAbvGr   1459 non-null   int64
#  5   BldgType       1459 non-null   object
#  6   BsmtCond       1414 non-null   object
#  7   BsmtExposure   1415 non-null   object
#  8   BsmtFinSF1     1458 non-null   float64
#  9   BsmtFinSF2     1458 non-null   float64
#  10  BsmtFinType1   1417 non-null   object
#  11  BsmtFinType2   1417 non-null   object
#  12  BsmtFullBath   1457 non-null   float64
#  13  BsmtHalfBath   1457 non-null   float64
#  14  BsmtQual       1415 non-null   object
#  15  BsmtUnfSF      1458 non-null   float64
#  16  CentralAir     1459 non-null   object
#  17  Condition1     1459 non-null   object
#  18  Condition2     1459 non-null   object
#  19  Electrical     1459 non-null   object
#  20  EnclosedPorch  1459 non-null   int64
#  21  ExterCond      1459 non-null   object
#  22  ExterQual      1459 non-null   object
#  23  Exterior1st    1458 non-null   object
#  24  Exterior2nd    1458 non-null   object
#  25  Fence          290 non-null    object
#  26  FireplaceQu    729 non-null    object
#  27  Fireplaces     1459 non-null   int64
#  28  Foundation     1459 non-null   object
#  29  FullBath       1459 non-null   int64
#  30  Functional     1457 non-null   object
#  31  GarageArea     1458 non-null   float64
#  32  GarageCars     1458 non-null   float64
#  33  GarageCond     1381 non-null   object
#  34  GarageFinish   1381 non-null   object
#  35  GarageQual     1381 non-null   object
#  36  GarageType     1383 non-null   object
#  37  GarageYrBlt    1381 non-null   float64
#  38  GrLivArea      1459 non-null   int64
#  39  HalfBath       1459 non-null   int64
#  40  Heating        1459 non-null   object
#  41  HeatingQC      1459 non-null   object
#  42  HouseStyle     1459 non-null   object
#  43  Id             1459 non-null   int64
#  44  Id.1           1459 non-null   int64
#  45  KitchenAbvGr   1459 non-null   int64
#  46  KitchenQual    1458 non-null   object
#  47  LandContour    1459 non-null   object
#  48  LandSlope      1459 non-null   object
#  49  LotArea        1459 non-null   int64
#  50  LotConfig      1459 non-null   object
#  51  LotFrontage    1232 non-null   float64
#  52  LotShape       1459 non-null   object
#  53  LowQualFinSF   1459 non-null   int64
#  54  MSSubClass     1459 non-null   int64
#  55  MSZoning       1455 non-null   object
#  56  MasVnrArea     1444 non-null   float64
#  57  MasVnrType     1443 non-null   object
#  58  MiscFeature    51 non-null     object
#  59  MiscVal        1459 non-null   int64
#  60  MoSold         1459 non-null   int64
#  61  Neighborhood   1459 non-null   object
#  62  OpenPorchSF    1459 non-null   int64
#  63  OverallCond    1459 non-null   int64
#  64  OverallQual    1459 non-null   int64
#  65  PavedDrive     1459 non-null   object
#  66  PoolArea       1459 non-null   int64
#  67  PoolQC         3 non-null      object
#  68  RoofMatl       1459 non-null   object
#  69  RoofStyle      1459 non-null   object
#  70  SaleCondition  1459 non-null   object
#  71  SaleType       1458 non-null   object
#  72  ScreenPorch    1459 non-null   int64
#  73  Street         1459 non-null   object
#  74  TotRmsAbvGrd   1459 non-null   int64
#  75  TotalBsmtSF    1458 non-null   float64
#  76  Utilities      1457 non-null   object
#  77  WoodDeckSF     1459 non-null   int64
#  78  YearBuilt      1459 non-null   int64
#  79  YearRemodAdd   1459 non-null   int64
#  80  YrSold         1459 non-null   int64
# dtypes: float64(11), int64(27), object(43)
# memory usage: 923.4+ KB

# %%
test = test.drop(columns=['Id.1', 'Alley', 'PoolQC', 'Fence', 'MiscFeature'])

# %%
test_id = test.pop('Id')

# %%
X_test_final = test.copy()

# %% [markdown]
# ## Train model an full dataset

# %%
X_train = X.copy()
y_train = y.copy()

# %%
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat_pipe',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value='N_A',
#                                                                                  strategy='constant')),
#                                                                   ('encoders',
#                                                                    ColumnTransformer(transformers=[('ordinal',
#                                                                                                     OrdinalEncoder(categories=[['Po',
#                                                                                                                                 'Fa',
#                                                                                                                                 'TA',
#                                                                                                                                 'Gd',
#                                                                                                                                 'Ex'],
#                                                                                                                                ['Po',
#                                                                                                                                 'Fa',
#                                                                                                                                 'TA',
#                                                                                                                                 'Gd',
#                                                                                                                                 'Ex'],
#                                                                                                                                ['Po',
#                                                                                                                                 'Fa',
#                                                                                                                                 'TA',
#                                                                                                                                 'Gd',
#                                                                                                                                 'Ex'],
#                                                                                                                                ['Po',
#                                                                                                                                 'Fa',
#                                                                                                                                 'TA',
#                                                                                                                                 'Gd',
#                                                                                                                                 'Ex'],
#                                                                                                                                ['No...
#                                                    'BedroomAbvGr',
#                                                    'OpenPorchSF', 'YearBuilt',
#                                                    'PoolArea', 'YearRemodAdd',
#                                                    'GarageArea', 'BsmtHalfBath',
#                                                    'LotFrontage', '3SsnPorch',
#                                                    'YrSold', '1stFlrSF',
#                                                    'BsmtFinSF2',
#                                                    'EnclosedPorch', 'MiscVal',
#                                                    'GrLivArea', 'LowQualFinSF',
#                                                    'GarageYrBlt',
#                                                    'KitchenAbvGr', 'BsmtUnfSF',
#                                                    'MoSold', 'TotalBsmtSF',
#                                                    'GarageCars', ...])])),
#                 ('estimator',
#                  KNeighborsClassifier(leaf_size=10, n_neighbors=7))])

# %%
result = model.predict(X_test_final)
# Out:
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fda8b208cc0>
# Traceback (most recent call last):
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/home/hristo/miniconda3/envs/wbs_bootcamp/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'

# %%
len(result)
# Out:
# 1459

# %%
len(test_id)
# Out:
# 1459

# %%
final = pd.DataFrame({
    'Id': test_id,
    'Expensive': result
})
final
# Out:
#         Id  Expensive
# 0     1461          0
# 1     1462          0
# 2     1463          0
# 3     1464          0
# 4     1465          0
# ...    ...        ...
# 1454  2915          0
# 1455  2916          0
# 1456  2917          0
# 1457  2918          0
# 1458  2919          0
#
# [1459 rows x 2 columns]

# %%
final.to_csv('winner.csv', index=False)
